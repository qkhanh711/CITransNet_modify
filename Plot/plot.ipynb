# %%
# %cd ..
# %cd CITransNet
# Out:
# /home/khanhnq/Code/Auction_optimal/CITransNet_modify
# /home/khanhnq/Code/Auction_optimal/CITransNet_modify/CITransNet

# %%
path = ["/result/train_5x3_True", "/result/train_5x3_False"]

import matplotlib.pyplot as plt
import json
import os
cwd = os.getcwd()
print(cwd)
continous_5x3 = path[0]
discrete_5x3 = path[1]
with open(cwd + continous_5x3 + "/train.json", "r") as f:
    train = json.load(f)
    projit = train["revenue"]
    plt.plot(projit, label="5x3")
    plt.legend()
    plt.show()
    
with open(cwd + discrete_5x3 + "/train.json", "r") as f:
    train = json.load(f)
    projit = train["revenue"]
    plt.plot(projit, label="5x3")
    plt.legend()
    plt.show()
# Out:
# /home/khanhnq/Code/Auction_optimal/CITransNet_modify/CITransNet
